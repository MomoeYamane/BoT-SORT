# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ./drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !pip install cython
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Cython-bbox
# !pip install cython_bbox

# faiss cpu / gpu
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-ms8vjwr0
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-ms8vjwr0
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp38-cp38-linux_x86_64.whl size=421066 sha256=46b292d228fc61f796f369f3694e0abc242fdce0d80c577a9dc863fce9e777cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0dm1ls04/wheels/56/da/49/cb71a7c450b59588934077f431100c05fbde50646ee84a8d40
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.6
# ...

# %%
# !git clone https://github.com/NirAharon/BoT-SORT.git
# Out:
# fatal: destination path 'BoT-SORT' already exists and is not an empty directory.

# %%
# %cd BoT-SORT
# !pip3 install -r requirements.txt
# !python3 setup.py develop
# Out:
# /content/drive/MyDrive/BoT-SORT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 30.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 KB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 31.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 97.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 KB 55.4 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/BoT-SORT/tools/mc_demo_yolov7.py --weights /content/drive/MyDrive/pretrained/yolov7-d6.pt --source /content/drive/MyDrive/BoT-SORT1/IMG_0126.MOV  --fuse-score --agnostic-nms --save-txt
# Out:
# Namespace(ablation=False, agnostic_nms=True, appearance_thresh=0.25, aspect_ratio_thresh=1.6, augment=False, classes=None, cmc_method='sparseOptFlow', conf_thres=0.09, device='', exist_ok=False, fast_reid_config='fast_reid/configs/MOT17/sbs_S50.yml', fast_reid_weights='pretrained/mot17_sbs_S50.pth', hide_labels_name=False, img_size=1920, iou_thres=0.7, jde=False, match_thresh=0.7, min_box_area=10, mot20=True, name='exp', new_track_thresh=0.4, nosave=False, project='runs/detect', proximity_thresh=0.5, save_conf=False, save_txt=True, source='/content/drive/MyDrive/BoT-SORT1/IMG_0126.MOV', trace=False, track_buffer=30, track_high_thresh=0.3, track_low_thresh=0.05, update=False, view_img=False, weights=['/content/drive/MyDrive/pretrained/yolov7-d6.pt'], with_reid=False)
# YOLOv7 🚀 2519854 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/BoT-SORT/tools/mc_demo_yolov7.py", line 282, in <module>
# ...
